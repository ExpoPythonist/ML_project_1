# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

import tensorflow as tf
from tensorflow import keras
from keras import datasets, layers, models

keras.utils.set_random_seed(42)

# %% [markdown]
# # Dataset
#
# I am a bolod
#
# - bolod 1
# - bolod 2

# %%
(X_train, y_train), (X_test, y_test) = datasets.mnist.load_data()

# Normalise pixel values to be between 0 and 1
X_train, X_test = X_train / 255.0, X_test / 255.0

print(f'{X_train.shape=} {y_train.shape=}')
print(f'{X_test.shape=} {y_test.shape=}')
# Out:
# X_train.shape=(60000, 28, 28) y_train.shape=(60000,)
# X_test.shape=(10000, 28, 28) y_test.shape=(10000,)

# %% [markdown]
# ## Plot digits

# %%
sample_data = X_train[:6]

fig, axs = plt.subplots(nrows=1, ncols=6)

for ax, img in zip(axs, sample_data):
    ax.imshow(img)
    ax.set_xticks([]); ax.set_yticks([])

# %% [markdown]
# # CNN model

# %%
model = models.Sequential([
    keras.Input(shape=(28,28,1)),
    layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(units=64, activation='relu'),
    layers.Dense(units=10, activation='softmax'),
])

model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %% [markdown]
# # Train

# %%
history = model.fit(
    x = X_train,
    y = y_train,
    validation_data=(X_test, y_test),
    batch_size=256,
    epochs=300,
    verbose=1,
    callbacks=[keras.callbacks.EarlyStopping(patience=3)],
)
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
# Out:
# Epoch 1/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 42ms/step - accuracy: 0.7699 - loss: 0.7944 - val_accuracy: 0.9722 - val_loss: 0.0860
# Epoch 2/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.9757 - loss: 0.0820 - val_accuracy: 0.9828 - val_loss: 0.0544
# Epoch 3/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9832 - loss: 0.0543 - val_accuracy: 0.9855 - val_loss: 0.0430
# Epoch 4/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.9879 - loss: 0.0406 - val_accuracy: 0.9859 - val_loss: 0.0403
# Epoch 5/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9906 - loss: 0.0327 - val_accuracy: 0.9875 - val_loss: 0.0376
# Epoch 6/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9926 - loss: 0.0271 - val_accuracy: 0.9875 - val_loss: 0.0381
# Epoch 7/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9937 - loss: 0.0235 - val_accuracy: 0.9872 - val_loss: 0.0373
# Epoch 8/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9940 - loss: 0.0210 - val_accuracy: 0.9878 - val_loss: 0.0368
# Epoch 9/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.9949 - loss: 0.0177 - val_accuracy: 0.9858 - val_loss: 0.0415
# Epoch 10/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9954 - loss: 0.0160 - val_accuracy: 0.9883 - val_loss: 0.0369
# Epoch 11/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9957 - loss: 0.0141 - val_accuracy: 0.9907 - val_loss: 0.0271
# Epoch 12/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9967 - loss: 0.0108 - val_accuracy: 0.9896 - val_loss: 0.0330
# Epoch 13/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.9971 - loss: 0.0100 - val_accuracy: 0.9907 - val_loss: 0.0322
# Epoch 14/300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9971 - loss: 0.0098 - val_accuracy: 0.9916 - val_loss: 0.0282
# 313/313 - 1s - 3ms/step - accuracy: 0.9916 - loss: 0.0289

# %%
def plot_history(history):
    acc,  val_acc  = history['accuracy'],  history['val_accuracy']
    loss, val_loss = history['loss'], history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5)); plt.subplot(1, 2, 1)
    
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy'); plt.legend(); plt.subplot(1, 2, 2)
    
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss'); plt.legend(); plt.show()
    
plot_history(history.history)

# %% [markdown]
# # Evaluate

# %%
y_pred = model.predict(X_test).argmax(1)

print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       980
#            1       0.99      1.00      0.99      1135
#            2       0.99      0.99      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.99      0.99      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.99      0.98      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
model.save('mnist-for-nova.keras')

# %% [markdown]
# # Demo

# %%
test_digits = X_test[:1]

preds = model.predict(test_digits).argmax(1)

fig, axs = plt.subplots(nrows=1, ncols=10, figsize=(12, 4))

for ax, pred, img in zip(axs, preds, test_digits):
    ax.imshow(img)
    ax.set_title(f'{pred=}')
    ax.set_xticks([]); ax.set_yticks([])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
